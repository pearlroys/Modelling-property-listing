# %%
import pandas as pd
from datetime import datetime
import re
pd.set_option('display.max_columns', None)

# %% [markdown]
# ****# **THE CELLS IN THIS NOTEBOOK ARE USED TO FOR EXPLORATORY ANALYSIS AND TO CLEAN UP THE DATA****

# %%
df = pd.read_csv('listing.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
# ...

# %%
df['bedrooms'].unique()
# Out:
# array([nan, '1', '2', '5', '3', '4', '8', '6',
#        'https://www.airbnb.co.uk/rooms/49009981?adults=1&category_tag=Tag%3A677&children=0&infants=0&search_mode=flex_destinations_search&check_in=2022-04-18&check_out=2022-04-25&previous_page_section_name=1000&federated_search_id=0b044c1c-8d17-4b03-bffb-5de13ff710bc',
#        '10', '7'], dtype=object)

# %%
df['beds'] = df['beds'].fillna(1)
df['guests'] = df['guests'].fillna(1)
df['bathrooms'] = df['bathrooms'].fillna(1)
df['bedrooms'] = df['bedrooms'].fillna(1)
df[df['beds'].isna()]
# df = df.dropna(subset=['Location_rating'],how='any')
# df
# Out:
# Empty DataFrame
# Columns: [ID, Category, Title, Description, Amenities, Location, guests, beds, bathrooms, Price_Night, Cleanliness_rating, Accuracy_rating, Communication_rating, Location_rating, Check-in_rating, Value_rating, amenities_count, url, bedrooms, Unnamed: 19]
# Index: []

# %%
df['Value_rating'].unique()
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              88
# Amenities                 0
# Location                  0
# guests                   19
# beds                     43
# bathrooms               100
# Price_Night               0
# Cleanliness_rating       98
# Accuracy_rating          98
# Communication_rating     98
# Location_rating          98
# Check-in_rating          98
# Value_rating             98
# amenities_count           0
# url                       0
# bedrooms                 82
# Unnamed: 19             987
# dtype: int64

# %%
usa_rows = df[df['Category'] == 'Treehouses']

# extract the values in the 'Name' column of the selected rows
usa_names = usa_rows['Value_rating']
usa_names.unique()
# Out:
# array([4.3, 4.5, 4.7, 4.6, nan, 4.4, 4.1, 4.8, 4.9, 5. , 4.2, 4. , 3.3])

# %%
import re

df['Description'].str.replace("'About this space',","")
df['Description'] = df['Description'].str.replace('"',"")
df['Description'] = df['Description'].str.replace("' '","")
df['Description'] = df['Description'].str.replace("'","")
df['Description'] = df['Description'].str.replace(r'\\n', '')
df['Description'] = df['Description'].str.replace(r'\\n\\', '')
df['Description'] = df['Description'].str.split(',', n=1).str[-1]
df['Description'] = df['Description'].str[:-2]
df= df.dropna(subset=['Description'])


# remove about this plce
df['Description'][5]
# Out:
# ' Charming cabin nestled in the leaves, real unusual and cozy house in the trees with all the modern comforts, just 45 minutes from Paris, 28 km from Disneyland or Provins and 5 minutes from the Parc des Félins. This cozy nest awaits you year-round for an unusual romantic or family experience. A parenthesis of relaxation and relaxation, ideal to offer yourself or yourself. See you soon :), The space, The space\\nLa Cabane Perchée de Chambonnière awaits you over the seasons and offers a comfortable and cozy setting amidst the trees, the opportunity to escape from everyday life during a romantic stay with two or family, for one or more nights.\\n\\nYou will be seduced by this treehouse full of charm with neat decoration.\\n- Access by gentle slope, ideal for welcoming you easily.\\n- Charming living room with bioethanol fireplace (only in cold weather and exclusively for couples or families with children over 7 years old)\\n- Fully equipped kitchen.\\n- Double bedroom + 1 bedroom with 
# ...

# %%
df['Description'][9]
# Out:
# ' Our lodges are pretty eco-chalets equipped with 2 bedrooms, bathroom, kitchen and living room. Their covered terrace will allow you to make the most of breakfast or aperitif because the luxury here is space and nature !For a week or more, treat yourself to a breath of fresh air in this nature hotel, unique in southern Brittany!, The space, The spaceDihan (break in Breton) is a very natural cocktail of history, unusual,travel, and love of Brittany.A few kilometers from the sea, between Carnac and Quiberon peninsula, thisoriginal structure, the first unusual European ecolabel site, precursor of nights in huts in the trees is an ecolodge born from the old family farm.Since then, many unusual accommodations have gradually nestled on our 25-hectare estate in Ploemel.Treehouses, yurts, hobbit houses... Get ready for an out-of-time experience, where vegetation is king ! Here, you can light up with a candle and a dynamo lamp and forget about your mobile phone...With a space dedicated to re
# ...
